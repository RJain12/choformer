# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
file = "../final_model_test.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0         Y    Target      Loss
# 0           0  0.708676  0.742915  0.034238
# 1           1  0.447323  0.544552  0.097229
# 2           2  0.403063  0.493073  0.090009
# 3           3  0.689136  0.730385  0.041249
# 4           4  0.659550  0.756347  0.096797

# %%
y = df["Y"].to_list()
target = df["Target"].to_list()

# %%
df["Target"].value_counts()
# Out:
# Target
# 2    511
# 1    372
# 0    252
# 3    162
# 4     33
# Name: count, dtype: int64

# %%
df["Y"].value_counts()
# Out:
# Y
# 2    884
# 4    263
# 3     82
# 0     61
# 1     40
# Name: count, dtype: int64

# %%
sns.heatmap(confusion_matrix(target, y), annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(target, y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.07      0.11       252
#            1       0.25      0.03      0.05       372
#            2       0.40      0.69      0.51       511
#            3       0.07      0.04      0.05       162
#            4       0.02      0.12      0.03        33
#
#     accuracy                           0.29      1330
#    macro avg       0.20      0.19      0.15      1330
# weighted avg       0.29      0.29      0.24      1330

# %%
df = pd.read_csv("../model_test.csv")

# %%
print(f"Losses:\nMean: {df['Loss'].mean()}\nStd: {df['Loss'].std()}")
# Out:
# Losses:
# Mean: 0.2797300803544875
# Std: 0.17959520178313887

# %%
sns.boxplot(df["Loss"])
# Out:
# <Axes: ylabel='Loss'>

# %%
sns.boxplot(df["Loss"])

# %%
sns.scatterplot(df, x="Target", y="Y")b
# Out:
# <Axes: xlabel='Target', ylabel='Y'>

# %%
sns.scatterplot(df, x="Target", y="Y")
# Out:
# <Axes: xlabel='Target', ylabel='Y'>

# %%
print(f"Y:\nMean: {df['Y'].mean()}\nStd: {df['Y'].std()}")
# Out:
# Y:
# Mean: 0.508927392700894
# Std: 0.25365916320370197

# %%
print(f"Target:\nMean: {df['Target'].mean()}\nStd: {df['Target'].std()}")
# Out:
# Target:
# Mean: 0.5081537356654916
# Std: 0.2913417597307413

# %%
df["Y"].plot.kde()
df["Target"].plot.kde()
# Out:
# <Axes: ylabel='Density'>
